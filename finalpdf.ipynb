# %%
# Out:
# no. of rows in commercial data : 402
# no. of columns in commercial data : 67
#
# no. of rows in others data : 316
# no. of columns in others data : 39
#
# no. of rows in others data : 453
# no. of columns in others data : 71
#
# Quse 1 : Are survey in commercial Unique ?
# Answer :  Surveys of commercial are unique - all entries in rows aren't same
#
# Quse 2 : Are survey in Others Unique ?
# Answer :  Surveys of Others are unique - all entries in rows aren't same
#
# Quse 3 : Are survey in res-cum-comm Unique ?
# Answer :  Surveys of res-cum-comm are unique
#
# Distribution of Survey ID length variation in commercial data
# ----------------------------------------------------------------------------
# Distribution of Survey ID length variation in Others data
# ----------------------------------------------------------------------------
# Distribution of Survey ID length variation in Res-cum-comm data
# ----------------------------------------------------------------------------
# ...
